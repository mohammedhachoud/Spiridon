# %% [markdown]
# # Tables Translation To English Notebook
# ## Features Translation
# ## Features_Ontology_PF.csv ( French) ---> Features_Ontology_PF_translated_file.csv (English)
# ## The names of Columns are kept same

# %%
import pandas as pd
import csv # Import csv module for quoting constants

# --- Configuration ---
input_csv_path = '/kaggle/input/db-data/Features_Ontology_PF.csv'
output_csv_path = '/kaggle/working/Features_Ontology_PF_translated_file.csv'

csv_delimiter = ','
csv_encoding = 'utf-8'

# --- Translation Mappings ---
feature_name_mapping = {
    "Cuisson": "Firing",
    "└ Atmosphère de cuisson": "Firing Atmosphere",
    " └ Oxydante": "Oxidizing",
    " └ Réductrice": "Reducing",
    " └ Aléatoire": "Random",
    "└ Traces d'enfournement": "Firing Marks",
    " └ Pernette": "Stilt mark",
    " └ Emboîtement": "Nesting",
    " └ Autre": "Other",
    "Décor": "Decoration",
    "└ Décor géométrique": "Geometric decoration",
    "└ Décor figuré": "Figurative decoration",
    "└ Décor zoomorphe": "Zoomorphic decoration",
    "└ Décor végétal": "Vegetal decoration",
    "└ Héraldique": "Heraldic",
    "└ Décor calligraphique": "Calligraphic decoration",
    "Façonnage": "Shaping",
    "└ Au tour": "Wheel-thrown",
    " └ Tourné": "Thrown",
    " └ Tourné/modelé": "Thrown / Modeled",
    "└ A la main": "Handmade",
    " └ Modelé": "Modeled",
    " └ Modelé/tournassé": "Modeled / Turned",
    " └ Découpé": "Cut",
    " └ Raclé": "Scraped",
    " └ Sur âme": "On core",
    "└ Au moule": "Molded",
    " └ Moulé": "Molded",
    " └ Coulé": "Cast",
    "Marques et signes": "Marks and Signs",
    "└ Marque de fabrique": "Maker's Mark",
    " └ Imprimée en creux": "Impressed",
    " └ Imprimée au tampon": "Stamped",
    " └ Incisée": "Incised",
    " └ Peinte": "Painted",
    " └ Moulée en relief": "Molded in relief",
    "└ Signes": "Signs",
    " └ Incisé post-cuisson": "Incised post-firing",
    " └ Peint": "Painted",
    " └ Incisé avant cuisson": "Incised pre-firing",
    " └ Imprimé en creux": "Impressed",
    " └ Moulé en relief": "Molded in relief",
    "Pâte": "Fabric",
    "└ Matrice": "Matrix",
    " └ Calcaire": "Calcareous",
    " └ Non calcaire": "Non-calcareous",
    "  └ Riche en fer": "Iron-rich",
    " └ Kaolinitique": "Kaolinitic",
    " └ Sableuse": "Sandy",
    " └ Artificielle": "Artificial",
    " └ Porcelaine": "Porcelain",
    " └ Siliceuse": "Siliceous",
    " └ Grès": "Stoneware",
    " └ Autre": "Other",
    "└ Inclusions/dégraissants": "Inclusions / Tempers",
    " └ Mica": "Mica",
    " └ Quartz": "Quartz",
    " └ Calcite/chaux": "Calcite / Lime",
    " └ Shiste": "Schist",
    " └ Végétal": "Vegetal",
    " └ Chamotte": "Chamotte",
    " └ Nodules ferreux": "Ferrous nodules",
    " └ Variées": "Varied",
    "Revêtement": "Coating",
    "└ Sans revêtement": "Without coating",
    "└ Glaçure ou émail": "Glaze or Tin",
    " └ Glaçure plombifère": "Lead glaze",
    " └ Émail": "Tin",
    " └ Glaçure alcaline": "Alkaline glaze",
    " └ Glaçure alcalino-plombifère": "Alkaline-lead glaze",
    " └ Glaçure au sel": "Salt glaze",
    "└ Engobe": "Slip",
    "Technique de décor or aspect de surface": "Decoration Technique or Surface Aspect",
    "└ Aspect de surface": "Surface Aspect",
    " └ Lissage": "Smoothed",
    " └ Blanchissement de surface": "Surface whitening",
    " └ Surface craquelée-bleutée": "Bluish crackled surface",
    " └ Cannelures": "Fluted",
    "└ Technique de décor": "Decoration Technique",
    " └ Polissage": "Polished",
    " └ Incisée": "Incised",
    " └ Peinte, pigment": "Painted, pigment",
    " └ Peinte, glaçure/émail": "Painted, glaze/Tin",
    " └ Peinte, structuré engobe": "Painted, structured slip",
    " └ Peinte, mêlé engobe et glaçure": "Painted, mixed slip and glaze",
    " └ Excisé": "Champlevé",
    " └ Imprimé": "Impressed",
    "  └ Imprimé à la molette": "Roulette impressed",
    "  └ Imprimé au poinçon ou au tampon": "Punched or stamped",
    " └ Repoussé": "Repoussé",
    " └ Moulé": "Molded",
    " └ Appliqué libre": "Freely applied",
    " └ Moulé appliqué": "Applied molded",
    " └ Découpé": "Cut",
    " └ Transfert": "Transfer",
    " └ Au pochoir": "Stenciled",
    " └ A l'éponge": "Sponged",
    " └ Guilloché": "Guilloché",
    " └ Digité": "Finger-impressed",
    " └ Hachuré": "Hatched",
    " └ Peinte, lustre métallique": "Luster Painted",
    " └ Festonné": "Festooned",
    " └ Incisée et/ou imprimée au peigne": "Incised and/or comb-impressed",
    " └ Au tampon": "Stamped",
    "Tourné sur âme": "Wheel-thrown on a core",
    "Excisé": "Excised",
    "Faïence fine": "Fine earthenware",
    "Incisé à la pointe": "Point-incised",
    "Incisé à la gouge": "Gouge-incised"

}

# Mappings for Nom complet 
nom_complet_mapping = {
    "Cuisson": "Firing",
    "Cuisson selon l'atmosphère": "Firing by atmosphere",
    "Cuisson en atmosphère oxydante": "Firing in oxidizing atmosphere",
    "Cuisson en atmosphère réductrice": "Firing in reducing atmosphere",
    "Cuisson en atmosphère non maîtrisée": "Firing in uncontrolled atmosphere",
    "Cuisson avec traces d’enfournement": "Firing with traces of stacking",
    "Cuisson avec traces de pernette": "Firing with tripod marks",
    "Cuisson avec traces d'emboîtement": "Firing with nesting marks",
    "Cuisson avec traces d'enfournement autre que pernettes et emboîtement/Cuisson avec traces d'enfournement atypique": "Firing with atypical stacking marks",
    "Décor": "Decoration",
    "Décor géométrique": "Geometric decoration",
    "Décor figuré": "Figural decoration",
    "Décor zoomorphe": "Zoomorphic decoration",
    "Décor végétal": "Plant/Vegetal decoration",
    "Décor Héraldique": "Heraldic decoration",
    "Décor calligraphique": "Calligraphic decoration",
    "Façonnage": "Forming",
    "Faconnage au tour": "Wheel-thrown forming",
    "Faconnage tourné": "Thrown forming",
    "Façonnage tourné et moulé": "Thrown and molded forming",
    "Faconnage à la main": "Hand forming",
    "Façonnage modelé": "Modeled forming",
    "Faconnage modelée et tournassé": "Modeled and smoothed forming",
    "Fcaonnage découpé": "Cut forming",
    "Faconnage raclé": "Scraped forming",
    "Faconnage montée sur âme": "Built on core forming",
    "Faconnage au moule": "Molded forming",
    "Faconnage moulée": "Mold-formed",
    "Faconnage coulée": "Slip cast forming",
    "Marques et signes": "Marks and Signs",
    "Marque de fabrique": "Manufacturer’s mark",
    "Marque imprimée en creux": "Impressed mark",
    "Marque imprimée au tampon": "Stamped mark",
    "Marque incisée": "Incised mark",
    "Marque peinte": "Painted mark",
    "Marque moulée en relief": "Molded in relief mark",
    "Signe de Fabrique ": "Fabric’s mark",
    "Signe incisé post-cuisson": "Post-firing incised sign",
    "Signe peint": "Painted sign",
    "Signe incisé avant cuisson": "Pre-firing incised sign",
    "Signe imprimé en creux": "Impressed sign",
    "Signe moulé en relief": "Molded in relief sign",
    "Pâte": "Fabric",
    "Pate avec Matrice": "Fabric with matrix",
    "Pâte calcaire": "Calcareous Fabric",
    "Pâte non calcaire": "Non-calcareous Fabric",
    "Pâte non calcaire riche en fer": "Iron-rich non-calcareous Fabric",
    "Pâte kaolinitique": "Kaolinitic Fabric",
    "Pâte sableuse": "Sandy Fabric",
    "Pâte artificielle": "Artificial Fabric",
    "Porcelaine": "Porcelain",
    "Pâte siliceuse": "Siliceous Fabric",
    "Grès": "Stoneware",
    "Pâte à matrice indéfinie": "Indeterminate matrix Fabric",
    "Pate avec Inclusion": "Fabric with Inclusion",
    "Pâte à inclusions de mica": "Fabric with mica inclusions",
    "Pâte à inclusions de quartz": "Fabric with quartz inclusions",
    "Pâte à inclusions de calcite ou de chaux": "Fabric with calcite or lime inclusions",
    "Pâte à inclusions de shiste": "Fabric with schist inclusions",
    "Pâte à inclusions végétales": "Fabric with vegetal inclusions",
    "Pâte à inclusions de chamotte": "Fabric with chamotte inclusions",
    "Pâte à inclusions de nodules ferreus": "Fabric with iron nodule inclusions",
    "Pâte à inclusions variées indéfinies": "Fabric with varied and indeterminate inclusions",
    "Revêtement": "Coating / Glaze",
    "Absence de revêtement": "No coating",
    "Glaçure ou émail": "Lead Glaze or tin glaze",
    "Glaçure plombifère": "Lead glaze",
    "Émail": "Tin Glaze",
    "Glaçure alcaline": "Alkaline glaze",
    "Glaçure alcalino-plombifère": "Alkaline-lead glaze",
    "Glaçure au sel": "Salt glaze",
    "Engobe": "Slip",
    "Technique de décor or aspect de surface": "Decorative Technique or Surface Aspect",
    "Aspect de surface ": "Surface aspect",
    "Lissage à la surface": "Surface smoothing",
    "Blanchissement de surface": "Surface whitening",
    "Surface craquelée-bleutée": "Bluish crackled surface",
    "Surface à cannelures": "Fluted surface",
    "Technique de décor": "Decoration Techniques",
    "Décor de polissage": "Polished decoration",
    "Décor incisé": "Incised decoration",
    "Décor peint au pigment": "Pigment-painted decoration",
    "Décor peint en glaçure ou à l’émail": "Glaze or tin-painted decoration",
    "Décor structuré, peint à l’engobe": "Slip painted Structured decoration",
    "Décor mêlé, peint à l’engobe et à la glaçure": "Mixed decoration, slip painted, glaze",
    "Décor excisé": "Champlevé",
    "Décor imprimé": "Printed decoration",
    "Décor imprimé à la molette": "Roulette-stamped decoration",
    "Décor imprimé au poinçon ou au tampon": "Impressed or stamped decoration",
    "Décor repoussé": "Repoussé decoration",
    "Décor moulé": "Molded decoration",
    "Décor appliqué libre": "Freely applied decoration",
    "Décor moulé et rapporté": "Molded and reported decoration",
    "Décor découpé": "Cut-out decoration",
    "Décor réalisé au transfert": "Transfer decoration",
    "Décor réalisé au pochoir": "Stenciled decoration",
    "Décor réalisé à l’éponge": "Sponged decoration",
    "Décor guilloché": "Guilloché decoration",
    "Décor digité": "Finger-impressed decoration",
    "Décor hachuré": "Hatched decoration",
    "Décor peint au lustre métallique": "Lustre-painted decoration",
    "Décor festonné": "Festooned decoration",
    "Decor incisé ou imprimé au peinge": "Incised or comb-printed decoration",
    "Décor peint au tampon": "Stamped decoration",
    "Décor incisé à la pointe": "Incised Ware decoration",
    "Décor incisé à la gouge": "Gouged Ware decoration",
    "Faconnage tournée sur âme": "Wheel-thrown forming on a core",
    "Décor excisé par prélèvement d’argile": "Excised decoration by clay removal",
    "Pâte artificielle pour la faïence fine": "Artificial fabric for fine earthenware"
}


# Mapping for the 'Ceramic_Relation' column (direct replacements)
ceramic_relation_map = {
    'Has_Cuisson': 'Has_Firing',
    'Has_Décor': 'Has_Decoration',
    'Has_Faconnage': 'Has_Forming',
    'Has_Marque': 'Has_Mark',
    'Has_Signe': 'Has_Sign',
    'Has_Pate': 'Has_Fabric',
    'Has_revetement': 'Has_Coating',
    'Has_Technique de décor or aspect de surface': 'Has_Decoration_Technique_or_Surface_Aspect',
    'Has_technique de décor': 'Has_Decoration_Technique',
    'Has_Aspect de surface': 'Has_Surface_Aspect',
}

# Mapping for the 'Nom abrégé avec la relation' column (direct replacements)
nom_abrege_map = {
    'Cuisson': 'Firing',
    "Cuisson selon l'atmosphère": 'Firing by atmosphere',
    "Cuisson avec traces d’enfournement": 'Firing with traces of stacking',
    'Décor': 'Decoration',
    'Faconnage': 'Forming',
    'Faconnage au tour': 'Thrown forming',
    'Faconnage à la main': 'Hand forming',
    'Faconnage au moule': 'Molded forming',
    'Marque ou signe': 'Marks or Signs',
    'Marque': 'Mark',
    'Signe de Fabrique': 'Factory Sign',
    'Pate': 'Fabric',
    'Matrice de pâte': 'Matrix of Fabric',
    'Inclusion dans la pâte': 'inclusion on Fabric',
    'revêtement': 'Coating',
    'Glaçure ou émail': 'Glaze or tin',
    'Technique de décor or aspect de surface': 'Decorative Technique or Surface Aspect',
    'Aspect de surface': 'Surface Aspect',
    'Technique de décor': 'Decorative Technique',
}




# --- Processing ---
print(f"Reading CSV file: {input_csv_path}")
try:
    df = pd.read_csv(input_csv_path, sep=csv_delimiter, encoding=csv_encoding)
    print("File read successfully.")
    print(f"Detected columns: {df.columns.tolist()}")
except FileNotFoundError:
    print(f"Error: File not found at {input_csv_path}")
    exit()
except Exception as e:
    print(f"An error occurred while reading the file: {e}")
    print("Please check the file path, delimiter, and encoding.")
    exit()

required_columns = ['feature_name_fr', 'Nom complet', 'Ceramic_Relation', 'Nom abrégé avec la relation']
for col in required_columns:
    if col not in df.columns:
        print(f"Error: Column '{col}' not found in the CSV file.")
        print(f"Available columns: {df.columns.tolist()}")
        exit()


# Apply translations
print("Applying translations...")

# Translate 'feature_name_fr' and create a new English column
if 'feature_name_fr' in df.columns:
    df['feature_name_fr'] = df['feature_name_fr'].map(feature_name_mapping).fillna(df['feature_name_fr'])
    print("Column 'feature_name_fr' translated to 'feature_name_english'.")

# Translate 'Nom complet' and create a new English column
if 'Nom complet' in df.columns:
     df['Nom complet'] = df['Nom complet'].map(nom_complet_mapping).fillna(df['Nom complet'])
     print("Column 'Nom complet' translated to 'Nom complet_english'.")

# Translate 'Ceramic_Relation' and overwrite the column
if 'Ceramic_Relation' in df.columns:
     df['Ceramic_Relation'] = df['Ceramic_Relation'].replace(ceramic_relation_map)
     print("Column 'Ceramic_Relation' translated (overwritten).")

# Translate 'Nom abrégé avec la relation' and overwrite the column
if 'Nom abrégé avec la relation' in df.columns:
     df['Nom abrégé avec la relation'] = df['Nom abrégé avec la relation'].replace(nom_abrege_map)
     print("Column 'Nom abrégé avec la relation' translated (overwritten).")

if 'cat_name' in df.columns:
    df['cat_name'] = df['cat_name'].map(cat_name_mapping).fillna(df['cat_name'])
    print("Column 'cat_name' translated (overwritten).")


# --- Save the translated file ---
print(f"Saving translated CSV file to: {output_csv_path}")
try:
    df.to_csv(output_csv_path, index=False, sep=csv_delimiter, encoding=csv_encoding, quoting=csv.QUOTE_ALL)
    print("Translation complete. File saved successfully.")
except Exception as e:
    print(f"An error occurred while saving the file: {e}")
# Out:
# Reading CSV file: /kaggle/input/db-data/Features_Ontology_PF.csv
# File read successfully.
# Detected columns: ['id', 'feature_name_fr', 'feature_parent', 'feature_grandpa', 'tree_depth', 'Nom complet', 'Relation', 'Ceramic_Relation', 'Nom abrégé avec la relation']
# Applying translations...
# Column 'feature_name_fr' translated to 'feature_name_english'.
# Column 'Nom complet' translated to 'Nom complet_english'.
# Column 'Ceramic_Relation' translated (overwritten).
# Column 'Nom abrégé avec la relation' translated (overwritten).
# Saving translated CSV file to: /kaggle/working/Features_Ontology_PF_translated_file.csv
# Translation complete. File saved successfully.

# %% [markdown]
# ## Categories Translation
# ## tech_cat.csv --> tech_cat_translated.csv
# ## Same, Columns Names Kept

# %%
import pandas as pd
import csv # Import csv module for quoting constants

input_csv_path = '/kaggle/input/db-data/tech_cat.csv'
output_csv_path = '/kaggle/working/tech_cat_translated.csv'

csv_delimiter = ','
csv_encoding = 'utf-8'

cat_name_mapping = {
    "Calcaire à glaçure alcaline / Raqqa": "Calcareous with alkaline glaze / Raqqa",
    "Architecturale sans revêtement / Alger": "Architectural, unglazed / Algiers",
    "Architecturale en pâtes artificielles": "Architectural, in artificial fabric",
    "Kaolinitique réductrice": "Kaolinitic, reducing-fired",
    "Incisées monochromes / Nicée-Iznik": "Incised monochrome / Nicea-Iznik",
    "Kaolinitiques glaçurées sur engobe / Saint-Quentin-la-Poterie": "Kaolinitic, glazed on slip / Saint-Quentin-la-Poterie",
    "Architecturale sans revêtement / Provence, Languedoc": "Architectural, unglazed / Provence, Languedoc",
    "Moulée glaçurée / Raqqa": "Moulded, glazed / Raqqa",
    "Calcaire oxydante peinte au pigment / Languedoc": "Calcareous, oxidizing-fired, painted with pigment / Languedoc",
    "Emaillée, décor vert et brun / Provence, Languedoc": "Tin Glazed, green and brown decoration / Provence, Languedoc",
    "Glaçure monochrome / Syrie, Egypte": "Monochrome glaze / Syria, Egypt",
    "Architecturale en pâte artificielle d'époque industrielle": "Architectural, in artificial fabric, Industrial period",
    "Calcaire oxydante / Provence, Languedoc": "Calcareous, oxidizing-fired / Provence, Languedoc",
    "Architecturale sans revêtement vitreux": "Architectural, unglazed (literally: without vitreous coating)",
    "Incisées et peintes / Aphrodisias": "Incised and painted / Aphrodisias",
    "Calcaire oxydante sans revêtement vitreux": "Calcareous, oxidizing-fired, unglazed",
    "Incisées et peintes / Anatolie turcomane": "Incised and painted / Turkoman Anatolia",
    "Peintes à l'engobe / Empire byzantin": "Slip Painted/ Byzantine Empire",
    "Céladon": "Celadon",
    "Glaçurées sur engobe / Nicée-Iznik": "Glazed on slip / Nicea-Iznik",
    "Décors d'engobe / Crimée": "Slip decoration / Crimea",
    "Incisées ou incisées et peintes sur engobe / Méditerranée orientale": "Incised or incised and painted on slip / Eastern Mediterranean",
    "Glaçurées sur engobe / Méditerranée orientale": "Glazed on slip / Eastern Mediterranean",
    "Kaolinitiques glaçurées sur engobe / Dieulefit": "Kaolinitic, glazed on slip / Dieulefit",
    "Architecturale en pâte artificielle / Iznik": "Architectural, in artificial fabric / Iznik",
    "Kaolinitique glaçurée": "Kaolinitic, glazed",
    "Glaçurées sur engobe / Chypre": "Glazed on slip / Cyprus",
    "Peintes à l'engobe / Nicée-Iznik": "Slip Painted/ Nicea-Iznik",
    "Glaçurée / Sud de l'Itale, Sicile, Maghreb": "Glazed / Southern Italy, Sicily, Maghreb",
    "Peinte avec des glaçures colorées": "Painted with colored glazes",
    "Culinaire / Catalogne": "Cooking ware / Catalonia",
    "Calcaire glaçurée / Famagouste": "Calcareous, glazed / Famagusta",
    "Emaillée, décor vert et brun / Catalogne": "Tin Glazed, green and brown painted / Catalonia",
    "Emaillée, décor bleu et brun / Maghreb": "Tin Glazed, blue and brown painted / Maghreb",
    "Sans revêtement peinte à l'engobe": "Unglazed, slip Painted",
    "Emaillée, décor bleu et brun / Italie du Nord": "Tin Glazed, blue and brown painted / Northern Italy",
    "Emaillées, décors bleu et brun": "Tin Glazed, blue and brown painted",
    "Emaillée / Italie": "Tin Glazed / Italy",
    "Emaillée, décor bleu ou polychrome ou au lustre / Catalogne": "Tin Glazed, blue or polychrome painted or with lustre decoration / Catalonia",
    "Incisées et peintes / Chypre": "Incised and painted / Cyprus",
    "Architecturale glaçurée / Alger": "Architectural, glazed / Algiers",
    "Peintes / Chypre": "Painted / Cyprus",
    "Catégories en pâtes artificielles": "Categories in artificial fabrics",
    "A taches de glaçure et/ou engobe, Provence, XVIIIe": "With glaze and/or slip spots/splashes, Provence, 18th century",
    "Incisées et peintes en vert et brun ": "Incised and painted in green and brown",
    "Oxydante à polissage ou lissée": "Oxidizing-fired with polishing or smoothing",
    "Cuisson réductrice": "Reducing firing",
    "Peintes / Empire ottoman": "Painted / Ottoman Empire",
    "Calcaire réductrice moderne / Languedoc": "Calcareous, modern reducing-fired / Languedoc",
    "Kaolinitique oxydante sans revêtement": "Kaolinitic, oxidizing-fired, unglazed",
    "Architecturale à revêtement opaque / Naples": "Architectural with opaque coating / Naples",
    "Céramique à décor de lustre métallique": "Luster Painted Ware",
    "Terres mêlées et glaçurées": "Mixed clays and glazed",
    "Céramique à glaçure alcalino-plombifère turquoise / Raqqa": "Ceramic with alkaline-lead turquoise glaze / Raqqa",
    "Glaçurées sur engobe / Lapithos": "Glazed on slip / Lapithos",
    "Calcaire à glaçure plombifère": "Calcareous with lead glaze",
    "Peinte au manganèse / Imitations d'Albisola": "Painted with manganese / Albisola Imitations",
    "Incisées monochromes / Beyrouth": "Incised monochrome / Beirut",
    "Emaillée médiévale": "Medieval Tin Glazed",
    "Sableuse oxydante / Montpellier": "Sandy, oxidizing-fired / Montpellier",
    "Emaillée moderne": "Modern Tin Glazed",
    "Calcaire à glaçure plombifère  / Provence, Languedoc": "Calcareous with lead glaze / Provence, Languedoc",
    "Incisées et peintes / Anatolie seldjoukide": "Incised and painted / Seljuk Anatolia",
    "Sableuse glaçurée sur engobe / Languedoc": "Sandy, glazed on slip / Languedoc",
    "Architecturale glaçurée / Provence": "Architectural, glazed / Provence",
    "Incisée monochrome / Provence, Languedoc": "Incised monochrome / Provence, Languedoc",
    "Culinaire / Syrie": "Cooking ware / Syria",
    "Culinaire modelée glaçurée / Chypre": "Hand made glazed Cooking Ware  / Cyprus",
    "Emaillée, décor vert et brun / Pise": "Tin Glazed, green and brown painted / Pisa",
    "Emaillée, décor bleu et brun ou polychrome / Italie du Sud, Sicile": "Tin Glazed, blue and brown or polychrome painted / Southern Italy, Sicily",
    "Architecturale à revêtement opaque / Provence": "Architectural with opaque coating / Provence",
    "Kaolinitique blanche glaçurée": "White kaolinitic, glazed",
    "Calcaire à glaçure plombifère / Alger": "Calcareous with lead glaze / Algiers",
    "Glaçurés jaspées / Raqqa": "Jaspered glazed / Raqqa",
    "Peinte en vert et brun / Nicosie": "Green and brown painted / Nicosia",
    "Culinaire du Sud-Ouest": "Cooking ware from the Southwest",
    "Porcelaine européenne": "European Porcelain",
    "Incisées et peintes / Paphos": "Incised and painted / Paphos",
    "Peintes en vert / Lapithos": "Green Painted / Lapithos",
    "Peintes à l'engobe / Aphrodisias": "Slip Painted/ Aphrodisias",
    "Calcaire oxydante sans revêtement / Nicosie": "Calcareous, oxidizing-fired, unglazed / Nicosia",
    "À taches de manganèse / Crimée": "With manganese spots / Crimea",
    "Emaillée monochrome / Nicosie": "Tin glazed Plain Ware / Nicosia",
    "Glaçurée sur engobe à depressions / Crimée": "Glazed on slip with depressions / Crimea",
    "Emaillée, décor vert et brun / Nicosie": "Tin glazed, green and brown painted / Nicosia",
    "Catégories à glaçures transparentes": "Categories with transparent glazes",
    "Glaçures turquoises alcalino-plombifères / Anatolie": "Alkaline-lead turquoise glazed / Anatolia",
    "Emaillée / Catalogne": "Tin glazed / Catalonia",
    "Architecturale glaçurée": "Architectural, glazed",
    "Architecturale à revêtement opaque vénéto-ligure": "Architectural with Veneto-Ligurian opaque coating",
    "Engobée et peinte ligure": "Ligurian slip-coated and painted",
    "Peinte / Damas": "Painted / Damascus",
    "Peintes polychromes / Beyrouth": "Polychrome painted / Beirut",
    "Réfractaire glaçurée": "Refractory, glazed",
    "Incisées monochromes / Nicosie": "Incised monochrome / Nicosia",
    "Glaçurée non-calcaire sur engobe / Languedoc": "Non-calcareous, glazed on slip / Languedoc",
    "Architecturale à revêtement opaque / Barcelone": "Architectural with opaque coating / Barcelona",
    "Calcaire oxydante sans revêtement / Raqqa": "Calcareous, oxidizing-fired, unglazed / Raqqa",
    "Glaçurées monochromes / Beyrouth": "Plain glazed / Beirut",
    "Architecturale à revêtement opaque / Delft": "Architectural with opaque coating / Delft",
    "Incisée et/ou découpé / Syrie, Egypte": "Incised and/or cut-out / Syria, Egypt",
    "Peinte polychrome / Syrie, Egypte": "Polychrome painted / Syria, Egypt",
    "Brune à grise / Pyrénées Orientales": "Brown to grey / Eastern Pyrenees",
    "Catégories décorées d'engobe(s)": "Slip Painted Wares",
    "Porcelaine de Meissen": "Meissen Porcelain",
    "Peinte / Empire ottoman": "Painted / Ottoman Empire",
    "Porcelaine asiatique": "Asian Porcelain",
    "Peinte en noir et bleu / Syrie, Egypte": "Black and blue painted ware / Syria, Egypt",
    "Glaçurées sur engobe / Nicosie": "Glazed on slip / Nicosia",
    "Décors d'engobes sur pâtes kaolinitiques / Provence": "Slip painted on kaolinitic Fabrics / Provence",
    "Incisées peintes / Nicée-Iznik": "Incised and painted / Nicea-Iznik",
    "Kaolinitique émaillée en vert et brun": "Kaolinitic, Green and brown Tin glazed",
    "Incisées ou incisées et peintes sur engobe / Méditerranée occidentale": "Incised or painted on slip / Western Mediterranean",
    "Incisées ou incisées et peintes sur engobe": "Incised or painted on slip",
    "Incisées monochromes / Raqqa": "Incised monochrome / Raqqa",
    "Glaçure monochrome alcalino-plombifère opacifiée à l'étain / période des Beylik": "Monochrome alkaline-lead glaze opacified with tin / Beylik period",
    "Glaçurées sur engobe / Aphrodisias": "Glazed on slip / Aphrodisias",
    "Rouge gaçurée moderne": "Modern red glazed",
    "Kaolinitique glaçurée sur engobe / Provence, Languedoc": "Kaolinitic, glazed on slip / Provence, Languedoc",
    "Décors découpés / Syrie ": "Cut-out decorations / Syria",
    "Modelée sans revêtement": "Hand made Unglazed",
    "Calcaire oxydante sans revêtement abbasside / Raqqa": "Abbasid Calcareous oxidizing-fired, unglazed / Raqqa",
    "Peinte au lustre métallique ": "Luster Painted",
    "Porcelaine de Chine": "Chinese Porcelain",
    "Calcaire avec glaçure alcaline ou alcalino-plombifère": "Calcareous with alkaline or alkaline-lead glaze",
    "Calcaire à revêtement opaque / Raqqa": "Calcareous with opaque coating / Raqqa",
    "Incisées peintes / Lapithos": "Incised and painted / Lapithos",
    "Pâte siliceuse artificielle / Orient": "Artificial siliceous fabric / Orient",
    "Catégories à revêtement opaque ou opacifié": "Categories with opaque or opacified coating",
    "Calcaire oxydante sans revêtement fatimide / Raqqa": "Calcareous, Fatimid, oxidizing-fired, unglazed / Raqqa",
    "Kaolinitiques à revêtements opaques": "Kaolinitic with opaque coatings",
    "Emaillée / Provence, Languedoc": "Tin glazed / Provence, Languedoc",
    "Architecturale à revêtement opaque / Valence": "Architectural with opaque coating / Valencia",
    "Incisées monochromes / Iznik": "Incised monochrome / Iznik",
    "Décors structurés et/ou peint d'engobes / Provence, Languedoc": "Structured and/or slip painted ware / Provence, Languedoc",
    "Kaolinitique imprimée ou peinte glaçurée / Nicée-Iznik": "Kaolinitic, impressed or painted, glazed / Nicea-Iznik",
    "Claçurée sur engobe / Crimée": "Glazed on slip / Crimea",
    "Décors marbrés / Italie": "Marbled decorations / Italy",
    "Incisées et/ou peintes aux glaçures colorées": "Incised and/or painted with colored glazes",
    "Grossière ou sableuse oxydante / Languedoc": "Coarse or sandy, oxidizing-fired / Languedoc",
    "Faïence fine": "Fine Faience",
    "Architecturale à revêtement opaque ou opacifié": "Architectural with opaque or opacified coating",
    "Grise provençale": "Provençal Grey",
    "Glaçure opaque ou opacifiée / Orient ": "Opaque or opacified glaze / Orient",
    "Cuerda seca": "Cuerda seca",
    "Réfractaire glaçurée moderne": "Modern refractory, glazed",
    "Oxydante polie languedocienne": "Languedoc polished oxidizing-fired",
    "Peinte au lustre métallique sur pâte argileuse / Orient islamique": "Luster Painted ware on clay body / Islamic Orient",
    "Porcelaine du Japon": "Japanese Porcelain",
    "Peintes avec des glaçures colorées sur engobe": "Painted with colored glazes on slip",
    "Engobées en rouge et blanc, incisées et peintes": "Slip-coated in red and white, incised and painted",
    "Incisées monochromes / Empire byzantin": "Incised monochrome / Byzantine Empire",
    "Incisées et peintes jaspées / Raqqa": "Incised and painted jaspered / Raqqa",
    "Peinte en vert et brun / Nicée-Iznik": "Green and brown Painted / Nicea-Iznik",
    "Décors d'engobes mêlés / Provence, Languedoc": "Marbled Ware / Provence, Languedoc",
    "Emaillée monochrome / Provence, Languedoc": "Monochrome Tin glazed / Provence, Languedoc",
    "Céramique peinte polychrome à glaçure alcalino-plombifère / Raqqa": "Polychrome painted alkaline-lead glazed ware / Raqqa",
    "A glaçure opaque jaune et décors peints / Raqqa": "Painted opaque yellow glazed ware / Raqqa",
    "Céramique à glaçure alcalino-plombifère monochrome / Raqqa": "Ceramic with alkaline-lead monochrome glaze / Raqqa",
    "Moulée / Raqqa": "Moulded / Raqqa",
    "Culinaire grise moderne / Languedoc": "Modern grey Cooking ware / Languedoc",
    "Marmites grises / Provence": "Grey cooking pots / Provence",
    "Modelée / Chypre": "Modelled / Cyprus",
    "Calcaire réductrice médiévale / Languedoc": "Calcareous, medieval reducing-fired / Languedoc",
    "Catégories à glaçures transparentes sur engobe": "Categories with transparent glazes on slip",
    "Moulées sans revêtement": "Moulded, unglazed",
    "Incisées et peintes / Syrie du Nord": "Incised and painted / Northern Syria",
    "Décors marbrés / Empire ottoman": "Marbled decorations / Ottoman Empire",
    "Pâte rouge et surface noire": "Red body and black surface",
    "Moulée / Crimée": "Moulded / Crimea",
    "Glaçurées sur engobe rouge / Chypre": "Glazed on red slip / Cyprus",
    "Peinte / Chypre": "Painted / Chypre",
    "Peinte en bleu sur engobe": "Blue Painted on slip",
    "Incisée/peinte de la Vallée de l'Huveaune": "Incised/painted from the Huveaune Valley",
    "Architecturale glaçurée sur engobe": "Architectural, glazed on slip",
    "Peinte à l'engobe / Iznik": "Slip Painted/ Iznik",
    "Calcaire glaçurée / Al-Andalus": "Calcareous, glazed / Al-Andalus",
    "Incisées et peintes / Empire byzantin": "Incised and painted / Byzantine Empire",
    "Décors d'engobe / Çanakkale": "Slip decoration / Çanakkale",
    "Glaçurée sur engobe / Méditerranée occidentale": "Glazed on slip / Western Mediterranean",
    "Réfractaire glaçurée / Ligurie": "Refractory, glazed / Liguria",
    "Incisées monochromes / Paphos": "Monochrome Incised / Paphos",
    "Sableuse": "Sandy ",
    "Peintes à l'engobe / Anatolie seldjoukide": "Slip Painted/ Seljuk Anatolia",
    "Architectural à revêtement opaque / Tunis": "Architectural with opaque coating / Tunis",
    "Incisées et peintes / Iznik": "Incised and painted / Iznik",
    "Emaillée / Djerba": "Tin glazed / Djerba",
    "Architecturale engobée": "Architectural, slip-coated",
    "Catégories sans revêtement vitreux": "Unglazed categories (literally: Categories without vitreous coating)",
    "Culinaire / Beyrouth": "Cooking ware / Beirut",
    "Kaolinitique peinte avec des glaçures colorées": "Kaolinitic, painted with colored glazes",
    "Glaçurée plombifère / Empire ottoman": "Lead-glazed / Ottoman Empire",
    "Calcaire sans revêtement / Khorassan": "Calcareous, unglazed / Khorasan",
    "Peintes à l'engobe / Chypre": "Slip Painted / Cyprus",
    "Peinte / Kütahya": "Painted / Kütahya",
    "Peinte / Çanakkale": "Painted / Çanakkale",
    "Glaçurées sur engobe / Iznik": "Glazed on slip / Iznik",
    "Calcaire glaçurée sur engobe / Provence, Languedoc": "Calcareous, glazed on slip / Provence, Languedoc",
    "Incisées / Crimée": "Incised / Crimea",
    "Modelée culinaire / côtes Méditerranéennes": "Hand Made cookin ware / Mediterranean coasts",
    "Glaçure alcaline peinte en vert ou turquoise / Khorassan": "Green or turquoise painted Alkaline Glazed  / Khorasan",
    "Kaolinitique à revêtements polychromes opaques / Byzance": "Kaolinitic with polychrome opaque coatings / Byzantium",
    "Kaolinitique imprimée et/ou peinte glaçurée": "Kaolinitic, printed and/or painted, glazed",
    "Décors d'engobe / Aubagne, Saint-Zacharie": "Slip Painted/ Aubagne, Saint-Zacharie",
    "Peinte / Iznik": "Painted / Iznik",
    "Peinte au manganèse / Albisola": "Painted with manganese / Albisola",
    "Glaçurées sur engobe / Aubagne, Saint-Zacharie": "Glazed on slip / Aubagne, Saint-Zacharie",
    "Glaçurée associée au Forum ware": "Glazed, associated with Forum ware",
    "Kaolinitiques glaçurées avec ou sans engobe / Cavalon/Coulon - Avignon": "Kaolinitic, glazed with or without slip / Cavalon/Coulon - Avignon",
    "Peinte / incisée du Val de Durance": "Painted / incised from the Durance Valley",
    "Peinte en vert, brun et jaune / Giroussens": "Green, brown and yellow Painted / Giroussens",
    "Kaolinitiques fines glaçurées / pays d'Apt-Castellet": "Fine kaolinitic, glazed / Apt-Castellet region",
    "Cuisson oxydante": "Oxidizing firing",
    "Grise médiévale": "Medieval Grey",
    "Rouge glaçurée médiévale": "Medieval red glazed",
    "Brune tournassée languedocienne": "Languedoc turned brown (wheel-thrown brown)",
    "Grossière ou sableuse réductrice / Languedoc": "Coarse or sandy, reducing-fired / Languedoc",
    "Sableuse / Syrie": "Sandy / Syria",
    "Kaolinitique du groupe Uzège": "Kaolinitic from the Uzège group",
    "Emaillée, décor bleu et/ou lustre / Espagne": "Tin glazed, blue and/or lustre decoration / Spain",
    "Marmites modelées / Languedoc": "Hand Made cooking pots / Languedoc",
    "Glaçurée sur engobe, époque pré-industrielle": "Glazed on slip, pre-industrial period",
    "Modelée / Turquie": "Hand Made / Turkey",
    "Kaolinitique / Ollières-Val de Trets": "Kaolinitic / Ollières-Val de Trets",
    "Kaolinitiques glaçurées sur engobe / Vallauris": "Kaolinitic, glazed on slip / Vallauris",
    "Calcaire réductrice médiévale / Provence": "Calcareous, medieval reducing-fired / Provence",
    "Faïence de Delft": "Delftware",
    "Peinte en vert et brun / Cox-Lomagne": "Green and brown Painted / Cox-Lomagne",
    "Argiles épurées, époque pré-industrielle": "Refined clays, pre-industrial period",
    "Modelée culinaire / Khorassan": "Hand Made cooking ware / Khorasan",
    "Calcaire à glaçure plombifère / Khorassan": "Lead Glazed Limestone Fabric Ware / Khorasan",
    "Tournée et engobée, sans revêtement vitreux": "Unglazed wheel-thrown sliped Ware",
    "Culinaire tournée sans revêtement / Khorassan": "Wheel-thrown unglazed cooking ware / Khorasan",
    "Peintes aux engobes / Iran, Transoxiane, Khorassan": "Slip painted Ware / Iran, Transoxiana, Khorasan",
    "Matériel d'enfournement": "Pottery kiln equipment",
    "Calcaire oxydante peinte au pigment": "Limestone fabric, oxidizing-fired, painted with pigment",
    "Calcaire glaçuré / Catalogne": "Glazed Limestone fabric,  / Catalonia",
    "Calcaire oxydante peinte au pigment et incisée / Espagne": "Limestone fabric oxidizing-fired, painted with pigment and Incised / Spain",
    "Bleu et blanc d'époque Ming": "Blue and White Porcelain, Ming period",
    "Peinte en noir sous glaçure bleu turquoise / Damas": "Black painted under turquoise glaze Ware / Damascus",
    "Peinte en bleu sous glaçure incolore / Syrie, Egypte" : "Blue painted under colourless glaze Ware / Syria, Egypt"
}


# --- Processing ---
print(f"Reading CSV file: {input_csv_path}")
try:
    # Use pd.read_csv instead of pd.read_excel
    df = pd.read_csv(input_csv_path, sep=csv_delimiter, encoding=csv_encoding)
    print("File read successfully.")
    print(f"Detected columns: {df.columns.tolist()}")
except FileNotFoundError:
    print(f"Error: File not found at {input_csv_path}")
    exit()
except Exception as e:
    print(f"An error occurred while reading the file: {e}")
    print("Please check the file path, delimiter, and encoding.")
    exit()

# Check if required columns exist
required_columns = ['cat_name']
for col in required_columns:
    if col not in df.columns:
        print(f"Error: Column '{col}' not found in the CSV file.")
        print(f"Available columns: {df.columns.tolist()}")
        # Exit if a required column is missing
        exit()


# Apply translations
print("Applying translations...")

# Translate 'cat_name' and OVERWRITE the original column
if 'cat_name' in df.columns:
    df['cat_name'] = df['cat_name'].map(cat_name_mapping).fillna(df['cat_name'])
    print("Column 'cat_name' translated (overwritten).")


# --- Save the translated file ---
print(f"Saving translated CSV file to: {output_csv_path}")
try:
    df.to_csv(output_csv_path, index=False, sep=csv_delimiter, encoding=csv_encoding, quoting=csv.QUOTE_ALL)
    print("Translation complete. File saved successfully.")
except Exception as e:
    print(f"An error occurred while saving the file: {e}")
# Out:
# Reading CSV file: /kaggle/input/db-data/tech_cat.csv
# File read successfully.
# Detected columns: ['id', 'cat_name', 'description', 'date_begin', 'date_end', 'creator', 'date_created', 'inherit_from', 'alternative_name', 'last_update']
# Applying translations...
# Column 'cat_name' translated (overwritten).
# Saving translated CSV file to: /kaggle/working/tech_cat_translated.csv
# Translation complete. File saved successfully.

# %% [markdown]
# ## Functions Translation
# ## object_function.csv --> object_function_translated.csv

# %%
import pandas as pd
import csv 

# --- Configuration ---
# Kaggle paths for your CSV file
input_csv_path = '/kaggle/input/db-data/object_function.csv' # <--- input file
output_csv_path = '/kaggle/working/object_function_translated.csv' # <--- Desired output file name

# --- CSV Reading Parameters ---
csv_delimiter = ','
csv_encoding = 'utf-8'

# --- Translation Mapping for the 'function_name_fr' column ---
function_name_mapping = {
    "service et table": "tableware and service",
    "bol": "bowl",
    "écuelle": "bowl",
    "bassin": "basin",
    "assiette": "plate",
    "forme à bec tubulaire": "form with tubular spout",
    "gourde": "flask",
    "cruche": "pitcher",
    "forme à anse de panier": "form with basket handle",
    "tasse": "cup",
    "gobelet": "tumbler",
    "stockage spécifique": "specific storage",
    "culinaire": "culinary",
    "olla": "olla",
    "marmite": "cooking pot",
    "jatte": "bowl",
    "lèchefritte": "drip pan",
    "poêlon": "saucepan",
    "plat": "dish",
    "toupin": "pot",
    "couvercle": "lid",
    "faisselle": "draining mold",
    "entonnoir": "funnel",
    "luminaire": "lighting device",
    "lampe": "lamp",
    "piété": "religious items",
    "bénitier": "holy water font",
    "crucifix": "crucifix",
    "pot d'aisance": "chamber pot",
    "bidet": "bidet",
    "pot à pomade": "pomade pot",
    "plat à barbe": "shaving bowl",
    "bugadier": "laundry pot",
    "feu": "fire-related items",
    "vestiges de fours et de cuisson": "remains of kilns and firing",
    "couvre feu": "ember cover",
    "brûle parfum": "incense burner",
    "pipe": "pipe",
    "trompe d'appel": "calling horn",
    "taraillettes": "small clay discs",
    "poupée": "doll",
    "jeton": "token",
    "séparateur de cuisson": "firing separator",
    "casette": "saggar",
    "cale": "kiln support",
    "barre de four": "kiln bar",
    "céramique technique ou d'artisanat": "technical or craft ceramic",
    "moule à sucre": "sugar mold",
    "pot à mélasse": "molasses pot",
    "alambic": "still",
    "poids": "weight",
    "bassin de malade": "sick-room basin",
    "tuyau": "pipe",
    "ibrik": "ibrik",
    "autre": "other",
    "tampon ou poinçon": "stamp or punch",
    "carreau": "tile",
    "jarron": "small jar",
    "vaisselle": "dishware",
    "spécifique": "specific",
    "outils": "tools",
    "architecture": "architectural ceramics",
    "chope": "mug",
    "chope mesure": "measuring mug",
    "pichet": "small pitcher",
    "coupelle": "small dish",
    "tirelire": "money box",
    "aquamanil": "aquamanile",
    "albarello": "albarello",
    "hygiène, toilette et santé": "hygiene, toilet, and health items",
    "crachoir": "spittoon",
    "rince-oeil": "eye bath",
    "vase de montre": "watch stand",
    "chevrette": "chevrette",
    "pot canon": "cannon pot",
    "creuset": "crucible",
    "moule": "mold",
    "chandelier ou bougeoir": "candlestick or candle holder",
    "crochet": "hook",
    "rondeau": "round cooking pot",
    "lanterne": "lantern",
    "crépine": "strainer",
    "brique": "brick",
    "brique spécifique": "specific brick",
    "faîtage": "ridge tile",
    "rive": "verge tile",
    "tuile": "roof tile",
    "tuile spécifique": "specific roof tile",
    "parfeuille": "underside roof tile",
    "tomette": "floor tile",
    "bordure jardin": "garden edging",
    "carreau de poêle": "stove tile",
    "élément architectural": "architectural element",
    "plaque de foyer": "hearth plate",
    "jarre": "jar",
    "bouteille": "bottle",
    "pot à conserve": "preserve pot",
    "pot à fraises": "strawberry pot",
    "pot à moutarde": "mustard pot",
    "pot à raisin": "grape pot",
    "vinaigrier": "vinegar pot",
    "fontaine": "fountain",
    "théière ou chocolatière": "teapot or chocolate pot",
    "forme à découpes": "form with cut-outs",
    "inconnue": "unknown",
    "billes": "marbles",
    "jouet": "toy",
    "enfumoir": "smoke pot",
    "abreuvoir": "drinking trough",
    "outils réfractaires de cuisson": "refractory firing tools",
    "forme à trous": "form with holes",
    "amphore": "amphora",
    "nichoir": "birdhouse",
    "godet de roue à eau": "water wheel bucket",
    "service à liquides": "liquid service",
    "pot à bec": "spouted pot",
    "fusaïole ou disque à trou": "spindle whorl or perforated disc",
    "perle": "bead",
    "support": "support",
    "mandrin": "mandrel",
    "cuvette de latrines": "latrine bowl",
    "bouchon": "stopper",
    "mortier": "mortar",
    "sifflet": "whistle",
    "cruche à filtre": "filter jug",
    "pot à fleur": "flower pot",
    "égouttoir, passoire": "draining rack, strainer",
    "assiette plate": "flat plate",
    "assiette profonde": "deep plate",
    "soucoupe": "saucer",
    "orjol": "storage jar",
    "dourque": "pot",
    "pot double": "double pot",
    "vase d'autel": "altar vase",
    "stockage et emballage": "storage and packaging",
    "vase de jardin": "garden vase",
    "salière": "salt cellar",
    "boîte à épices": "spice box",
    "accessoire": "accessory",
    "saucière": "sauceboat",
    "soupière": "soup tureen",
    "findjan": "findjan",
    "pégau": "jug",
    "pot": "pot",
    "pot à bec pincé": "pot with pinched spout",
    "pot à bec tubulaire": "pot with tubular spout",
    "pot à bec à plaque": "pot with plate spout",
    "statuette": "statuette",
    "pot de chaise percée": "chamber pot",
    "chapeau d'alambic": "still head",
    "couvercle de service à liquide": "liquid service lid",
    "pot à ouverture polylobée": "pot with polylobed opening",
    "pot à anse(s)": "pot with handle(s)",
    "outils de potier": "potter's tools",
    "pot à bord rentrant": "pot with inverted rim",
    "couvercle à ergot": "lid with lug",
    "figurine": "figurine",
    "réchaud": "brazier",
    "scorie": "slag",
    "mouton": "sheep figurine",
    "chemisage de four": "kiln lining",
    "sole": "kiln floor",
    "terre rubéfiée": "rubified earth",
    "transport": "transport",
    "soucoupe de pot à fleur": "flower pot saucer",
    "vase à fleurs": "flower vase",
    "fleurs et jardin": "flowers and garden items",
    "aiguière": "ewer",
    "coupe": "cup",
    "biberon": "feeding bottle",
    "zellige": "zellige",
    "plat de service": "serving dish",
    "pot à crème ou à lait": "cream pot or milk jug",
    "beurrier": "butter dish",
    "boîte de toilette": "toilet box",
    "tuile canal": "Gutter tile",
    "tuile mécanique": "Interlocking tile",
    "tuile plate écaille":	"Beavertail tile",
    "tuile plate rectangulaire":	"Flat tile",
    "tuyau à collerette":	"Collared pipe",
    "tuyau coudé":	"Bent pipe",
    "tuyau spécifique":	"Specific pipe",
    "élément de gouttière":	"Gutter element",
    "chantepleure":	"Chantepleure"
}


# --- Processing ---
print(f"Reading CSV file: {input_csv_path}")
try:
    
    df = pd.read_csv(input_csv_path, sep=csv_delimiter, encoding=csv_encoding)
    print("File read successfully.")
    print(f"Detected columns: {df.columns.tolist()}")
except FileNotFoundError:
    print(f"Error: File not found at {input_csv_path}")
    exit()
except Exception as e:
    print(f"An error occurred while reading the file: {e}")
    print("Please check the file path, delimiter, and encoding.")
    exit()

# Check if the 'function_name_fr' column exists
required_column = 'function_name_fr'
if required_column not in df.columns:
    print(f"Error: Column '{required_column}' not found in the CSV file.")
    print(f"Available columns: {df.columns.tolist()}")
    exit() # Exit if the required column is missing

# Apply translation to the 'function_name_fr' column, overwriting original values
print(f"Applying translation to '{required_column}' column...")
df[required_column] = df[required_column].map(function_name_mapping).fillna(df[required_column])
print(f"Column '{required_column}' translated.")


# --- Save the translated file ---
print(f"Saving translated CSV file to: {output_csv_path}")
try:
    df.to_csv(output_csv_path, index=False, sep=csv_delimiter, encoding=csv_encoding, quoting=csv.QUOTE_ALL)
    print("Translation complete. File saved successfully.")
except Exception as e:
    print(f"An error occurred while saving the file: {e}")
# Out:
# Reading CSV file: /kaggle/input/db-data/object_function.csv
# File read successfully.
# Detected columns: ['id', 'function_name_fr', 'function_level', 'function_parent', 'function_disembiguation_fr', 'function_priority']
# Applying translation to 'function_name_fr' column...
# Column 'function_name_fr' translated.
# Saving translated CSV file to: /kaggle/working/object_function_translated.csv
# Translation complete. File saved successfully.
